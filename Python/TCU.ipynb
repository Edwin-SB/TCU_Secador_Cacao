# %%
#Aquí importamos las librerías
# Se Importa las respectivas librerias a utilizar a lo largo del programa
import os
import numpy as np 
from scipy import stats 
import matplotlib.pyplot as plt
import pandas as pd
from fitter import Fitter
import math
from scipy.stats import rayleigh

# Se crea la variable excel, que es donde alamacena lo leido por parte pandas del CSV
excel1 = pd.read_csv('Datos_Productor.csv')
excel2 = pd.read_csv('Datos_Secador_Cacao.csv')
# se crea la variable df(dataFrame) donde se alamcena los datos obtenidos por medio de la libreria pandas
df=pd.DataFrame(excel1)
df1=pd.DataFrame(excel2)


__author__ = "EdwinSB"



def Menu():

    print("                       ÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍ»")
    print("                       º                      :: TCU-230 ::                                    º")
    print("                       ÌÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍ¹")
    print("                       º                                                                       º")
    print("                       º  1.- InsertarID        2.-Nuevo ID           3.- Buscar ID.           º")
    print("                       º                                                                       º")
    print("                       º  4.- Borrar Pant       5.- Menú              6.- Version              º")
    print("                       º                                                                       º")
    print("                       º  7.- SALIR                                                            º")
    print("                       ÈÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍ¼")
    print("")

def mcd(num1, num2):
    a = max(num1, num2)
    b = min(num1, num2)
    while b!=0:
        mcd = b
        b = a%b
        a = mcd
    return mcd

def mcm(num1, num2):
    a = max(num1, num2)
    b = min(num1, num2)
    mcm = (a / mcd(a, b)) * b
    return mcm

def borrarPantalla():
    if os.name == "posix":
        os.system ("clear")
    elif os.name == "ce" or os.name == "nt" or os.name == "dos":
        os.system ("cls")

def Calculadora():

    Menu()

    opc = int(input("Selecione nº de Opción: "))

    while (opc >0 and opc <8):

        
        if(opc==1):
            print("")
            print("Insertar ID Productor:")
            ID = input()
            print(f"Buscando archivos de: {ID}")
            extension = '.csv'
            excel = ID + extension
            print(excel)
            
            
            
            df2.groupby('humedad')['humedad'].plot(kind='bar')
            plt.title('Productor ID :')
            plt.xlabel('Hora')
            plt.ylabel('Humedad')
            fig_temp = ID + 'humedad'
            plt.savefig(fig_temp)

            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")

            if Continuar == "s" or Continuar == "S":
                opc = 1

            elif Continuar == "n" or Continuar == "N":
                print(" ")
                opc = int(input("Selecione nº de Opción: "))

            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")

                if Continuar == "s" or Continuar == "S":
                    opc = 1

                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opc = int(input("Selecione nº de Opción: "))


        elif(opc==2):
            print("")
            New_ID = int(input("Insertar Nuevo ID Productor: "))
            print("")
            nombre = input("Insertar Nombre Productor: ")
            print("")
            apellido1 = input("Insertar Primer apellido Productor: ")
            print("")
            apellido2 = input("Insertar Segundo apellido Productor: ")
            print("")
            print('Nuevo productor agregado:',nombre,"",apellido1,"",apellido2,"",'ID:',New_ID)
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")

            if Continuar == "s" or Continuar == "S":
                opc = 2

            elif Continuar == "n" or Continuar == "N":
                print("")
                opc = int(input("Selecione nº de Opción: "))

            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")

                if Continuar == "s" or Continuar == "S":
                    opc = 2

                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opc = int(input("Selecione nº de Opción: "))

        
        elif(opc==6):
            print("")
            print("    ========================     Autores   =============================")
            print("    |                                                                  |")
            print("    |   Universidad de Costa Rica                                      |")
            print("    |   Sede Rodrigo Facio                                             |")
            print("    |                                                                  |")
            print("    | Profesores a cargo:                                              |")
            print("    |                                                                  |")
            print("    |                                                                  |")
            print("    | Estudiante: Edwin Somarribas Barahona                            |")
            print("    | Carné: B16453                                                    |")
            print("    |                                                                  |")
            print("    |                                                                  |")
            print("    |                                                                  |")
            print("    | Autor: Edwin Somarribas Barahona                                 |")
            print("    | Correo: edwinsb26@gmail.com                                      |")
            print("    | github: https://github.com/Edwin-SB/TCU_Secador_Cacao            |")                         
            print("    ====================================================================")
           
            opc = int(input("Selecione nº de Opción: "))

        elif(opc==4):
            borrarPantalla()
            Menu()
            opc = int(input("Selecione nº de Opción: "))
            
        elif(opc==3):
            opc1 = int(input("Inserte ID a buscar : "))
            dato1=df[df['Id']==opc1]['Nombre']
            dato2=df[df['Id']==opc1]['Primer apellido']
            dato3=df[df['Id']==opc1]['Segundo apellido']
            dato4=int(df[df['Id']==opc1]['Lote'])
            dato5=int(df[df['Id']==opc1]['Cantidad (Kg)'])
            dato6=df[df['Id']==opc1]['Tipo']
            totalDatos1 = dato1 + " " + dato2 + " " + dato3
            totalDatos2 = dato4
            print('ID buscado: ',opc ,'Datos Productor: ',totalDatos1)
            print('Lote:',dato4,'Cantidad (Kg):',dato5,'Tipo:',dato6)
            Continuar = input("¿Desea Continuar con esta Opción?(S/N): ")

            if Continuar == "s" or Continuar == "S":
                opc = 3

            elif Continuar == "n" or Continuar == "N":
                print(" ")
                opc = int(input("Selecione nº de Opción: "))

            else:
                print("")
                Continuar = input("Por Favor escoja(S/N): ")

                if Continuar == "s" or Continuar == "S":
                    opc = 3

                elif Continuar == "n" or Continuar == "N":
                    print("")
                    opc = int(input("Selecione nº de Opción: "))
        elif(opc==5):
            Menu()
            opc = int(input("Selecione nº de Opción: "))

        elif(opc==7):
            exit(0)

    while(opc <1 or opc >6 ):
        print("")
        print("Opción no Encontrada")
        print("")
        opc = int(input("Selecione nº de Opción: "))

Calculadora()
# Out:
#                        ÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍ»
#                        º                      :: TCU-230 ::                                    º
#                        ÌÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍ¹
#                        º                                                                       º
#                        º  1.- InsertarID        2.-Nuevo ID           3.- Buscar ID.           º
#                        º                                                                       º
#                        º  4.- Borrar Pant       5.- Menú              6.- Version              º
#                        º                                                                       º
#                        º  7.- SALIR                                                            º
#                        ÈÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍ¼
#
# Selecione nº de Opción: 3
# Inserte ID a buscar : 6453
# ID buscado:  3 Datos Productor:  0    Edwin Somarribas Barahona
# dtype: object
# Lote: 1 Cantidad (Kg): 5 Tipo: 0    criollo
# Name: Tipo, dtype: object
# ¿Desea Continuar con esta Opción?(S/N): s
# Inserte ID a buscar : 1234
# ID buscado:  3 Datos Productor:  1    Juan A D
# dtype: object
# Lote: 1 Cantidad (Kg): 5 Tipo: 1    criollo
# Name: Tipo, dtype: object
# ¿Desea Continuar con esta Opción?(S/N): n
#
# Selecione nº de Opción: 4
#                        ÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍ»
#                        º                      :: TCU-230 ::                                    º
#                        ÌÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍ¹
#                        º                                                                       º
#                        º  1.- InsertarID        2.-Nuevo ID           3.- Buscar ID.           º
#                        º                                                                       º
#                        º  4.- Borrar Pant       5.- Menú              6.- Version              º
#                        º                                                                       º
#                        º  7.- SALIR                                                            º
#                        ÈÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍÍ¼
